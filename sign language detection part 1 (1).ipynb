# %%
import pandas as pd
import numpy as np
from mpl_toolkits import mplot3d
# %matplotlib inline
import matplotlib.pyplot as plt
data= read_csv('C:\\Users\\lenovo\\3D Objects\\major project final dataset hand 1\\afternoon_apurve_1.txt')

# %%
a=np.array([-0.3772191,0.6764629,2.477132,-0.3672488,0.4930182,2.566909,-0.529421,0.3558396,2.57627,-0.1943015,0.4311023,2.561145,-0.5675833,0.08756277,2.615399,-0.03334243,0.5791205,2.433389,-0.5894274,-0.1222883,2.591342,-0.1127574,0.7756686,2.344967,-0.5723279,-0.2112776,2.548121,-0.1788912,0.8131377,2.315454,-0.3496525,0.1472809,2.577553,-0.3463077,0.0782887,2.574845,-0.419842,-0.005263386,2.57652,-0.2643511,0.007698199,2.571115,-0.4584759,-0.4603404,2.673417,-0.2359848,-0.4796088,2.666875,-0.4610319,-0.8478795,2.715237,-0.2295792,-0.8651484,2.683695,-0.4660459,-0.8985245,2.631478,-0.2079941,-0.9369207,2.647322])
x=np.array(a[0:61:3])
y=np.array(a[1:61:3])
z=np.array(a[2:61:3])
bone_list = [[1, 2],[2,3],[2,4],[3,5],[4,6],[5,7],[6,8],[7,9],[8,10],[2,11],[11,12],[12,13],[12,14],[13,15],[14,16],[15,17],[17,19],[16,18],[18,20]]
bone_list = np.array(bone_list) - 1
fig, ax = plt.subplots(1, figsize=(3, 8))
#fig = plt.figure()
#ax = plt.axes(projection='3d')
plt.title('Skeleton')
plt.xlim(-0.8,0.4)
plt.ylim(-1.5,1.5)

#ax.scatter3D(x, y, z,s=40)
#ax.scatter(x, y,s=40)

#ax.set_xlim(-0.8,-0.1)
#ax.set_ylim(-0.5,1.5)
#ax.set_zlim(-3,4)
for bone in bone_list:
    ax.plot([x[bone[0]], x[bone[1]]], [y[bone[0]], y[bone[1]]],[z[bone[0]], z[bone[1]]], 'r')
